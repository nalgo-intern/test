# %% [markdown]
# <a href="https://colab.research.google.com/github/nalgo-intern/test/blob/feature/Hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
h = "Hello"
w = "World"
print(f'{h},{w}.')
# Out:
# Hello,World.
